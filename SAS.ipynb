# %%
#  read data from excel file
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data= pd.read_excel('J:\\SATS\\20230126 SATS Sep-Oct data with success-bays-actual_time.xlsx', sheet_name='Sheet3',parse_dates=['Actual_Connection_Time'])

# %%
data.columns
# Out:
# Index(['ArrivalFlight', 'ORIGIN', 'Arrival_Gate', 'SIBTDateTimeOffset',
#        'ArrivalFlight & Date', 'ArrFlt_SIBT', 'SIBT', 'Day in Week',
#        'EIBTDateTimeOffset', 'EIBT', 'AIBTDateTimeOffset', 'AIBT',
#        'DepartureFlight', 'Dep_Gate', 'DepartureFlight & Date', 'DESTINATION',
#        'SOBTDateTimeOffset', 'SOBT', 'EOBTDateTimeOffset',
#        'Flight_Departure_Time', 'EOBT', 'AOBTDateTimeOffset', 'AOBT',
#        'Actual_Connection_Time', 'ID', 'AdultFirstBookedCount',
#        'ChildFirstBookedCount', 'InfantFirstBookedCount',
#        'AdultBusinessBookedCount', 'ChildBusinessBookedCount',
#        'InfantBusinessBookedCount', 'AdultPremiumBookedCount',
#        'ChildPremiumBookedCount', 'InfantPremiumBookedCount',
#        'AdultEconomyBookedCount', 'ChildEconomyBookedCount',
#        'InfantEconomyBookedCount', 'EOBT2', 'ConnectTime (SOBT-SIBT)',
#        'ConnectTime (EOBT-EIBT)', 'Duration', 'Protection_Cost',
#        'AdultFirstAcceptedCount', 'ChildFirstAcceptedCount',
#        'InfantFirstAcceptedCount', 'AdultBusinessAcceptedCount',
#        'ChildBusinessAcceptedCount', 'InfantBusinessAcceptedCount',
#        'AdultPremiumAcceptedCount', 'ChildPremiumAcceptedCount',
#        'InfantPremiumAcceptedCount', 'AdultEconomyAcceptedCount',
#        'ChildEconomyAcceptedCount', 'InfantEconomyAcceptedCount',
#        'Accepted_Total', 'FirstClassBagCount', 'BusinessClassBagCount',
#        'PremiumClassBagCount', 'EconomyClassBagCount', 'Total_Bag_Count',
#        'FirstClassBagsWeight', 'BusinessClassBagsWeight',
#        'PremiumClassBagsWeight', 'SQPassengerCountInfo_ID', 'Missed_AF',
#        'Missed_CF', 'Missed_IF', 'Missed_AJ', 'Missed_CJ', 'Missed_IJ',
#        'Missed_APY', 'Missed_CPY', 'Missed_IPY', 'Missed_AY', 'Missed_CY',
#        'Missed_IY', 'Missed_Total', 'Missed_Y/N', '% Success'],
#       dtype='object')

# %%
datatemp=data[['ArrivalFlight','ORIGIN','SIBT','DESTINATION','Arrival_Gate','Dep_Gate','Actual_Connection_Time','% Success']]

# %%
datatemp.head()
# Out:
#   ArrivalFlight     ORIGIN                SIBT DESTINATION Arrival_Gate  \
# 0         SQ208  Melbourne 2022-09-30 16:15:00      London           B2
# 1         SQ208  Melbourne 2022-09-30 16:15:00   New Dehli           B2
# 2         SQ208  Melbourne 2022-09-30 16:15:00      Manila           B2
# 3         SQ208  Melbourne 2022-09-30 16:15:00   Ahmedabad           B2
# 4         SQ208  Melbourne 2022-09-30 16:15:00       Seoul           B2
#
#   Dep_Gate Actual_Connection_Time  % Success
# 0       A2    2023-01-26 00:34:00        1.0
# 1       A2    2023-01-26 00:34:00        1.0
# 2       A2    2023-01-26 00:34:00        0.0
# 3       A2    2023-01-26 00:34:00        1.0
# 4       A2    2023-01-26 00:34:00        1.0

# %%
#  Take all data where Actual_Connection_Time is greater than 60 minutes
datatemp.dtypes
# Out:
# ArrivalFlight                     object
# ORIGIN                            object
# SIBT                      datetime64[ns]
# DESTINATION                       object
# Arrival_Gate                      object
# Dep_Gate                          object
# Actual_Connection_Time    datetime64[ns]
# % Success                        float64
# dtype: object

# %%
#  convert Actual_Connection_Time to datetime
# datatemp.tail()
# take minutes from Actual_Connection_Time
# convert actual time to seconds

# datatemp['Actual_Connection_Time1']=datatemp['Actual_Connection_Time'].dt.minute*60+datatemp['Actual_Connection_Time'].dt.second


# datatemp['Actual_Connection_Time1']=pd.to_datetime(datatemp['Actual_Connection_Time'], format='%Y-%m-%d %H:%M:%S')
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_8048\601241441.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datatemp['Actual_Connection_Time1']=datatemp['Actual_Connection_Time'].dt.minute*60+datatemp['Actual_Connection_Time'].dt.second

# %%
#  where Actual_Connection_Time is greater than 3600
datatemp.shape
# Out:
# (105700, 10)

# %%
#where actual_connection_time_new is greater than 3600:
datatemp1=datatemp[datatemp['Actual_Connection_Time_new']<3600]
# datatemp['Actual_Connection_Time1']=datatemp['Actual_Connection_Time1'].dt.minute*60+datatemp['Actual_Connection_Time1'].dt.second

# %%
datatemp1.shape
# Out:
# (4103, 10)

# %%
# flightBay['Same Bay'] = (flightBay['StandPosition'].str[0].isin(['A','B']) & flightBay['StandPosition2'].str[0].isin(['A','B'])) | (flightBay['StandPosition'].str[0].isin(['C','D']) & flightBay['StandPosition2'].str[0].isin(['C','D'])) |(flightBay['StandPosition'].str[0].isin(['E','F']) & flightBay['StandPosition2'].str[0].isin(['E','F']))

# %%
# save data to excel file
datatemp1.to_excel('J:\\SATS\\sixtyminutesSAS.xlsx', sheet_name='Sheet1')

# %%
datatemp1.groupby(['ArrivalFlight','Arrival_Gate','Dep_Gate','% Success']).count()
# Out:
#                                                ORIGIN  SIBT  DESTINATION  \
# ArrivalFlight Arrival_Gate Dep_Gate % Success
# 3K766         C11          B5       0.0             1     1            1
# BA015         D46          A4       0.0             1     1            1
#               D49          B4       0.0             1     1            1
#                                     1.0             1     1            1
# CX691         C23          B10      1.0             1     1            1
# ...                                               ...   ...          ...
# TR605         C17R         B6       1.0             1     1            1
# TR635         B9           B2       0.0             1     1            1
# TR905         D30          A14      1.0             3     3            3
# UK105         A12          F60      0.0             1     1            1
# UK115         305          F42      0.0             2     2            2
#
#                                                Actual_Connection_Time  \
# ArrivalFlight Arrival_Gate Dep_Gate % Success
# 3K766         C11          B5       0.0                             1
# BA015         D46          A4       0.0                             1
#               D49          B4       0.0                             1
#                                     1.0                             1
# CX691         C23          B10      1.0                             1
# ...                                                               ...
# TR605         C17R         B6       1.0                             1
# TR635         B9           B2       0.0                             1
# TR905         D30          A14      1.0                             3
# UK105         A12          F60      0.0                             1
# UK115         305          F42      0.0                             2
#
#                                                Actual_Connection_Time1  \
# ArrivalFlight Arrival_Gate Dep_Gate % Success
# 3K766         C11          B5       0.0                              1
# BA015         D46          A4       0.0                              1
#               D49          B4       0.0                              1
#                                     1.0                              1
# CX691         C23          B10      1.0                              1
# ...                                                                ...
# TR605         C17R         B6       1.0                              1
# TR635         B9           B2       0.0                              1
# TR905         D30          A14      1.0                              3
# UK105         A12          F60      0.0                              1
# UK115         305          F42      0.0                              2
#
#                                                Actual_Connection_Time_new
# ArrivalFlight Arrival_Gate Dep_Gate % Success
# 3K766         C11          B5       0.0                                 1
# BA015         D46          A4       0.0                                 1
#               D49          B4       0.0                                 1
#                                     1.0                                 1
# CX691         C23          B10      1.0                                 1
# ...                                                                   ...
# TR605         C17R         B6       1.0                                 1
# TR635         B9           B2       0.0                                 1
# TR905         D30          A14      1.0                                 3
# UK105         A12          F60      0.0                                 1
# UK115         305          F42      0.0                                 2
#
# [1098 rows x 6 columns]

# %%
#  group by Flight, Arrival_Gate, Dep_Gate, against success% values

datatemp2=datatemp1.groupby(['ArrivalFlight','Arrival_Gate','Dep_Gate','% Success'])['SIBT'].count()

# %%
datatemp2.head()
# Out:
# ArrivalFlight  Arrival_Gate  Dep_Gate  % Success
# 3K766          C11           B5        0.0          1
# BA015          D46           A4        0.0          1
#                D49           B4        0.0          1
#                                        1.0          1
# CX691          C23           B10       1.0          1
# Name: SIBT, dtype: int64

# %%
datatemp3=datatemp1.groupby(['Arrival_Gate','Dep_Gate','% Success'])['SIBT'].count()

# %%
datatemp1.groupby(['Arrival_Gate','Dep_Gate','% Success']).count()
# Out:
#                                  ArrivalFlight  ORIGIN  SIBT  DESTINATION  \
# Arrival_Gate Dep_Gate % Success
# 305          F42      0.000000               2       2     2            2
# A1           A12      0.800000               2       2     2            2
#                       0.937500               2       2     2            2
#                       1.000000              40      40    40           40
#              A14      0.000000               1       1     1            1
# ...                                        ...     ...   ...          ...
# F60          F35      1.000000               1       1     1            1
#              F54      0.368421               1       1     1            1
#                       0.545455               1       1     1            1
#                       0.750000               1       1     1            1
#                       1.000000              10      10    10           10
#
#                                  Actual_Connection_Time  \
# Arrival_Gate Dep_Gate % Success
# 305          F42      0.000000                        2
# A1           A12      0.800000                        2
#                       0.937500                        2
#                       1.000000                       40
#              A14      0.000000                        1
# ...                                                 ...
# F60          F35      1.000000                        1
#              F54      0.368421                        1
#                       0.545455                        1
#                       0.750000                        1
#                       1.000000                       10
#
#                                  Actual_Connection_Time1  \
# Arrival_Gate Dep_Gate % Success
# 305          F42      0.000000                         2
# A1           A12      0.800000                         2
#                       0.937500                         2
#                       1.000000                        40
#              A14      0.000000                         1
# ...                                                  ...
# F60          F35      1.000000                         1
#              F54      0.368421                         1
#                       0.545455                         1
#                       0.750000                         1
#                       1.000000                        10
#
#                                  Actual_Connection_Time_new
# Arrival_Gate Dep_Gate % Success
# 305          F42      0.000000                            2
# A1           A12      0.800000                            2
#                       0.937500                            2
#                       1.000000                           40
#              A14      0.000000                            1
# ...                                                     ...
# F60          F35      1.000000                            1
#              F54      0.368421                            1
#                       0.545455                            1
#                       0.750000                            1
#                       1.000000                           10
#
# [1034 rows x 7 columns]

# %%
datatemp1.nunique()
# Out:
# ArrivalFlight                 136
# ORIGIN                         65
# SIBT                          417
# DESTINATION                    63
# Arrival_Gate                   77
# Dep_Gate                       58
# Actual_Connection_Time        111
# % Success                     143
# Actual_Connection_Time1       111
# Actual_Connection_Time_new    111
# dtype: int64

# %%
datatemp3.head()
# Out:
# Arrival_Gate  Dep_Gate  % Success
# 305           F42       0.0000        2
# A1            A12       0.8000        2
#                         0.9375        2
#                         1.0000       40
#               A14       0.0000        1
# Name: SIBT, dtype: int64

# %%
datatemp1.groupby(['Arrival_Gate','Dep_Gate','% Success']).size()
# Out:
# Arrival_Gate  Dep_Gate  % Success
# 305           F42       0.000000      2
# A1            A12       0.800000      2
#                         0.937500      2
#                         1.000000     40
#               A14       0.000000      1
#                                      ..
# F60           F35       1.000000      1
#               F54       0.368421      1
#                         0.545455      1
#                         0.750000      1
#                         1.000000     10
# Length: 1034, dtype: int64

# %%
#  save datatemp3 to excel file
datatemp3.to_excel('J:\\SATS\\sixtyminutesSAS1.xlsx', sheet_name='Sheet2')

# %%
# Out:
# (1034,)

# %%
#  unique values of Arrival_Gate and Dep_Gate:
datatemp3['Arrival_Gate','Dep_Gate'].groupby(['Arrival_Gate','Dep_Gate']).count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:988, in Series.__getitem__(self, key)
#     986 try:
#     987     # For labels that don't resolve as scalars like tuples and frozensets
# --> 988     result = self._get_value(key)
#     990     return result
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:1092, in Series._get_value(self, label, takeable)
#    1091 # Similar to Index.get_value, but we do not fall back to positional
# -> 1092 loc = self.index.get_loc(label)
#    1093 return self.index._get_values_for_loc(self, loc, label)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\multi.py:2951, in MultiIndex.get_loc(self, key, method)
#    2950 if start == stop:
# -> 2951     raise KeyError(key)
#    2953 if not follow_key:
#
# KeyError: ('Arrival_Gate', 'Dep_Gate')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [45], line 2
#       1 #  unique values of Arrival_Gate and Dep_Gate:
# ----> 2 datatemp3['Arrival_Gate','Dep_Gate'].unique()
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:998, in Series.__getitem__(self, key)
#     992     except (KeyError, TypeError, InvalidIndexError):
#     993         # InvalidIndexError for e.g. generator
#     994         #  see test_series_getitem_corner_generator
#     995         if isinstance(key, tuple) and isinstance(self.index, MultiIndex):
#     996             # We still have the corner case where a tuple is a key
#     997             # in the first level of our MultiIndex
# --> 998             return self._get_values_tuple(key)
#    1000 if is_iterator(key):
#    1001     key = list(key)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:1066, in Series._get_values_tuple(self, key)
#    1063     raise KeyError("key of type tuple not found and not a MultiIndex")
#    1065 # If key is contained, would have returned by now
# -> 1066 indexer, new_index = self.index.get_loc_level(key)
#    1067 return self._constructor(self._values[indexer], index=new_index).__finalize__(
#    1068     self
#    1069 )
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\multi.py:3018, in MultiIndex.get_loc_level(self, key, level, drop_level)
#    3015 else:
#    3016     level = [self._get_level_number(lev) for lev in level]
# -> 3018 loc, mi = self._get_loc_level(key, level=level)
#    3019 if not drop_level:
#    3020     if lib.is_integer(loc):
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\multi.py:3098, in MultiIndex._get_loc_level(self, key, level)
#    3095         pass
#    3097 # partial selection
# -> 3098 indexer = self.get_loc(key)
#    3099 ilevels = [i for i in range(len(key)) if key[i] != slice(None, None)]
#    3100 if len(ilevels) == self.nlevels:
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\multi.py:2951, in MultiIndex.get_loc(self, key, method)
#    2948         raise KeyError(key) from err
#    2950 if start == stop:
# -> 2951     raise KeyError(key)
#    2953 if not follow_key:
#    2954     return slice(start, stop)
#
# KeyError: ('Arrival_Gate', 'Dep_Gate')

# %%
#  save datatemp1 to excel file:
datatemp2.to_excel('J:\\SATS\\sixtyminutesgroupSAS.xlsx', sheet_name='Sheet1')

# %%
datatemp['Actual_Connection_Time_new']=datatemp['Actual_Connection_Time'].dt.hour*(60*60)+datatemp['Actual_Connection_Time'].dt.minute*60+datatemp['Actual_Connection_Time'].dt.second
datatemp.head()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_8048\3285314572.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datatemp['Actual_Connection_Time_new']=datatemp['Actual_Connection_Time'].dt.hour*(60*60)+datatemp['Actual_Connection_Time'].dt.minute*60+datatemp['Actual_Connection_Time'].dt.second
#   ArrivalFlight     ORIGIN                SIBT DESTINATION Arrival_Gate  \
# 0         SQ208  Melbourne 2022-09-30 16:15:00      London           B2
# 1         SQ208  Melbourne 2022-09-30 16:15:00   New Dehli           B2
# 2         SQ208  Melbourne 2022-09-30 16:15:00      Manila           B2
# 3         SQ208  Melbourne 2022-09-30 16:15:00   Ahmedabad           B2
# 4         SQ208  Melbourne 2022-09-30 16:15:00       Seoul           B2
#
#   Dep_Gate Actual_Connection_Time  % Success  Actual_Connection_Time1  \
# 0       A2    2023-01-26 00:34:00        1.0                     2040
# 1       A2    2023-01-26 00:34:00        1.0                     2040
# 2       A2    2023-01-26 00:34:00        0.0                     2040
# 3       A2    2023-01-26 00:34:00        1.0                     2040
# 4       A2    2023-01-26 00:34:00        1.0                     2040
#
#    Actual_Connection_Time_new
# 0                        2040
# 1                        2040
# 2                        2040
# 3                        2040
# 4                        2040

# %% [markdown]
# datatemp['Actual_Connection_Time_new']=datatemp['Actual_Connection_Time'].dt.hour*(60*60)+datatemp['Actual_Connection_Time'].dt.minute*60+datatemp['AActual_Connection_Time'].dt.second
# datatemp.head()

# %%
datatemp['Actual_Connection_Time_new'].shape
# Out:
# (105700,)

# %%
# all data where Actual_Connection_Time is greater than 3600 seconds
datatemp1=datatemp[datatemp['Actual_Connection_Time_new']<=3600]

# %%
datatemp1.shape
# Out:
# (4343, 10)

# %%
#  all rows where Actual_Connection_Time1 is greater than 60 
datatemp1=datatemp[datatemp['Actual_Connection_Time_new']<3600]

# %%
datatemp1.shape
# Out:
# (4103, 10)

# %%
# save datatemp1
datatemp1.to_excel('J:\\SATS\\data.xlsx')

# %%
datatemp1.head()
# Out:
#   ArrivalFlight     ORIGIN                SIBT DESTINATION Arrival_Gate  \
# 0         SQ208  Melbourne 2022-09-30 16:15:00      London           B2
# 1         SQ208  Melbourne 2022-09-30 16:15:00   New Dehli           B2
# 2         SQ208  Melbourne 2022-09-30 16:15:00      Manila           B2
# 3         SQ208  Melbourne 2022-09-30 16:15:00   Ahmedabad           B2
# 4         SQ208  Melbourne 2022-09-30 16:15:00       Seoul           B2
#
#   Dep_Gate Actual_Connection_Time  % Success  Actual_Connection_Time1
# 0       A2    2023-01-26 00:34:00        1.0                       34
# 1       A2    2023-01-26 00:34:00        1.0                       34
# 2       A2    2023-01-26 00:34:00        0.0                       34
# 3       A2    2023-01-26 00:34:00        1.0                       34
# 4       A2    2023-01-26 00:34:00        1.0                       34

# %%
datatemp.dtypes
# Out:
# ArrivalFlight                      object
# ORIGIN                             object
# SIBT                       datetime64[ns]
# DESTINATION                        object
# Arrival_Gate                       object
# Dep_Gate                           object
# Actual_Connection_Time             object
# % Success                         float64
# Actual_Connection_Time1            object
# dtype: object

# %%
datatemp.head()
# Out:
#   ArrivalFlight     ORIGIN                SIBT DESTINATION Arrival_Gate  \
# 0         SQ208  Melbourne 2022-09-30 16:15:00      London           B2
# 1         SQ208  Melbourne 2022-09-30 16:15:00   New Dehli           B2
# 2         SQ208  Melbourne 2022-09-30 16:15:00      Manila           B2
# 3         SQ208  Melbourne 2022-09-30 16:15:00   Ahmedabad           B2
# 4         SQ208  Melbourne 2022-09-30 16:15:00       Seoul           B2
#
#   Dep_Gate  Duration  % Success Duration1
# 0       A2  14:10:00        1.0  14:10:00
# 1       A2  06:00:00        1.0  06:00:00
# 2       A2  03:35:00        0.0  03:35:00
# 3       A2  05:40:00        1.0  05:40:00
# 4       A2  06:25:00        1.0  06:25:00

# %%
datatemp.dtypes
# Out:
# ArrivalFlight            object
# ORIGIN                   object
# SIBT             datetime64[ns]
# DESTINATION              object
# Arrival_Gate             object
# Dep_Gate                 object
# Duration                 object
# % Success               float64
# Duration1                object
# dtype: object

# %%
#  convert duration1 to datetime type
datatemp['Duration1']=pd.to_datetime(datatemp['Duration1'], format='%H:%M:%S').dt.time
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_22036\3544712204.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datatemp['Duration1']=pd.to_datetime(datatemp['Duration1'], format='%H:%M:%S').dt.time

# %%
datatemp.head()
# Out:
#   ArrivalFlight     ORIGIN                SIBT DESTINATION Arrival_Gate  \
# 0         SQ208  Melbourne 2022-09-30 16:15:00      London           B2
# 1         SQ208  Melbourne 2022-09-30 16:15:00   New Dehli           B2
# 2         SQ208  Melbourne 2022-09-30 16:15:00      Manila           B2
# 3         SQ208  Melbourne 2022-09-30 16:15:00   Ahmedabad           B2
# 4         SQ208  Melbourne 2022-09-30 16:15:00       Seoul           B2
#
#   Dep_Gate  Duration  % Success
# 0       A2  14:10:00        1.0
# 1       A2  06:00:00        1.0
# 2       A2  03:35:00        0.0
# 3       A2  05:40:00        1.0
# 4       A2  06:25:00        1.0

# %%
datatemp.head()
# Out:
#   ArrivalFlight     ORIGIN                SIBT DESTINATION Arrival_Gate  \
# 0         SQ208  Melbourne 2022-09-30 16:15:00      London           B2
# 1         SQ208  Melbourne 2022-09-30 16:15:00   New Dehli           B2
# 2         SQ208  Melbourne 2022-09-30 16:15:00      Manila           B2
# 3         SQ208  Melbourne 2022-09-30 16:15:00   Ahmedabad           B2
# 4         SQ208  Melbourne 2022-09-30 16:15:00       Seoul           B2
#
#   Dep_Gate Duration  % Success
# 0       A2    14:10        1.0
# 1       A2    06:00        1.0
# 2       A2    03:35        0.0
# 3       A2    05:40        1.0
# 4       A2    06:25        1.0

# %%
# convert string  to datetime type
datatemp['Duration1']=pd.to_datetime(datatemp['Duration'], format='%M:%S').dt.time
# datatemp['Duration']=pd.to_datetime(datatemp['Duration'], format=':%M:%S').dt.time
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_22036\126979931.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datatemp['Duration1']=pd.to_datetime(datatemp['Duration'], format='%M:%S').dt.time

# %%
datatemp3.head()
# Out:
# Arrival_Gate  Dep_Gate  % Success
# 305           F42       0.0000        2
# A1            A12       0.8000        2
#                         0.9375        2
#                         1.0000       40
#               A14       0.0000        1
# Name: SIBT, dtype: int64

# %%
#  save file to csv
datatemp3.to_csv('J:\\SATS\\sixtyminutesSAS1.csv')

# %%
datatemp4.head()
# Out:
# % Success              0.000000  0.032258  0.034483  0.035714  0.050000  \
# Arrival_Gate Dep_Gate
# 305          F42            2.0       NaN       NaN       NaN       NaN
# A1           A12            NaN       NaN       NaN       NaN       NaN
#              A14            1.0       NaN       NaN       NaN       NaN
#              A17            NaN       NaN       NaN       NaN       NaN
#              B1             NaN       NaN       NaN       NaN       NaN
#
# % Success              0.076923  0.083333  0.087719  0.090909  0.115385  ...  \
# Arrival_Gate Dep_Gate                                                    ...
# 305          F42            NaN       NaN       NaN       NaN       NaN  ...
# A1           A12            NaN       NaN       NaN       NaN       NaN  ...
#              A14            NaN       NaN       NaN       NaN       NaN  ...
#              A17            NaN       NaN       NaN       NaN       NaN  ...
#              B1             NaN       NaN       NaN       NaN       NaN  ...
#
# % Success              0.977273  0.977778  0.979167  0.981481  0.982143  \
# Arrival_Gate Dep_Gate
# 305          F42            NaN       NaN       NaN       NaN       NaN
# A1           A12            NaN       NaN       NaN       NaN       NaN
#              A14            NaN       NaN       NaN       NaN       NaN
#              A17            NaN       NaN       NaN       NaN       NaN
#              B1             NaN       NaN       NaN       NaN       NaN
#
# % Success              0.983607  0.985714  0.986111  0.989011  1.000000
# Arrival_Gate Dep_Gate
# 305          F42            NaN       NaN       NaN       NaN       NaN
# A1           A12            NaN       NaN       NaN       NaN      40.0
#              A14            NaN       NaN       NaN       NaN       7.0
#              A17            NaN       NaN       NaN       NaN       5.0
#              B1             NaN       NaN       NaN       NaN       5.0
#
# [5 rows x 143 columns]

# %%
# read csv fie
datatemp4=pd.read_csv('J:\\SATS\\sixtyminutesSAS1.csv')

# %%
datatemp4.head()
# Out:
#   Arrival_Gate Dep_Gate  % Success  SIBT
# 0          305      F42     0.0000     2
# 1           A1      A12     0.8000     2
# 2           A1      A12     0.9375     2
# 3           A1      A12     1.0000    40
# 4           A1      A14     0.0000     1

# %%
datatemp4['Same Bay'] = (datatemp4['Arrival_Gate'].str[0].isin(['A','B']) & datatemp4['Dep_Gate'].str[0].isin(['A','B'])) | (datatemp4['Arrival_Gate'].str[0].isin(['C','D']) & datatemp4['Dep_Gate'].str[0].isin(['C','D'])) |(datatemp4['Arrival_Gate'].str[0].isin(['E','F']) & datatemp4['Dep_Gate'].str[0].isin(['E','F']))

# %%
datatemp4.head()
# Out:
#   Arrival_Gate Dep_Gate  % Success  SIBT  Same Bay
# 0          305      F42     0.0000     2     False
# 1           A1      A12     0.8000     2      True
# 2           A1      A12     0.9375     2      True
# 3           A1      A12     1.0000    40      True
# 4           A1      A14     0.0000     1      True

# %%
#  save file to csv
datatemp4.to_csv('J:\\SATS\\sixtyminutesSASwithBay.csv')

# %%
#  read csv file
datatemp4=pd.read_csv('J:\\SATS\\weighted_average.csv')

# %%
datatemp4.head()
# Out:
#   Arrival_Gate Dep_Gate         0
# 0          305      F42  0.000000
# 1           A1      A12  0.988068
# 2           A1      A14  0.829545
# 3           A1      A17  1.000000
# 4           A1       B1  1.000000

# %%
# datatemp5['Multi']=datatemp5['% Success']*datatemp5['SIBT']
datatemp4['Terminal'] = (datatemp4['Arrival_Gate'].str[0].isin(['A','B']) & datatemp4['Dep_Gate'].str[0].isin(['A','B'])) | (datatemp4['Arrival_Gate'].str[0].isin(['C','D']) & datatemp4['Dep_Gate'].str[0].isin(['C','D'])) |(datatemp4['Arrival_Gate'].str[0].isin(['E','F']) & datatemp4['Dep_Gate'].str[0].isin(['E','F']))

# %%
datatemp4.head()
# Out:
#   Arrival_Gate Dep_Gate         0  Terminal
# 0          305      F42  0.000000     False
# 1           A1      A12  0.988068      True
# 2           A1      A14  0.829545      True
# 3           A1      A17  1.000000      True
# 4           A1       B1  1.000000      True

# %%
# rename column
datatemp4.rename(columns={'0':'Weighted_Average'}, inplace=True)

# %%
# save file to csv
datatemp4.to_csv('J:\\SATS\\weighted_averagenew.csv')

# %%
weighted_average = (datatemp5.groupby(['Arrival_Gate','Dep_Gate'])['Multi'].sum() ) / datatemp5.groupby(['Arrival_Gate','Dep_Gate'])['SIBT'].sum()

# %%
weighted_average.head()
# Out:
# Arrival_Gate  Dep_Gate
# 305           F42         0.000000
# A1            A12         0.988068
#               A14         0.829545
#               A17         1.000000
#               B1          1.000000
# dtype: float64

# %%
# save file to csv
weighted_average.to_csv('J:\\SATS\\weighted_average.csv')

# %%
#  read csv file
weighted_average=pd.read_csv('J:\\SATS\\weighted_average.csv')

# %%
weighted_average['Terminal']=

# %%
weighted_average.shape
# Out:
# (390,)

# %%
datatemp5.head()
# Out:
#   Arrival_Gate Dep_Gate  % Success  SIBT   Multi
# 0          305      F42     0.0000     2   0.000
# 1           A1      A12     0.8000     2   1.600
# 2           A1      A12     0.9375     2   1.875
# 3           A1      A12     1.0000    40  40.000
# 4           A1      A14     0.0000     1   0.000

# %%
grouped = datatemp.groupby(['Arrival_Gate','Dep_Gate'])

# then we calculate the weighted average for each group
# weighted_average = (grouped['% Success'] * grouped['SIBT']).sum() / grouped['SIBT'].sum()

# %%
grouped.head()
# Out:
#        ArrivalFlight            ORIGIN                SIBT  DESTINATION  \
# 0              SQ208         Melbourne 2022-09-30 16:15:00       London
# 1              SQ208         Melbourne 2022-09-30 16:15:00    New Dehli
# 2              SQ208         Melbourne 2022-09-30 16:15:00       Manila
# 3              SQ208         Melbourne 2022-09-30 16:15:00    Ahmedabad
# 4              SQ208         Melbourne 2022-09-30 16:15:00        Seoul
# ...              ...               ...                 ...          ...
# 105154         TR491     Kota Kinabalu 2022-10-01 05:50:00  Los Angeles
# 105155         TR491     Kota Kinabalu 2022-10-01 05:50:00        Perth
# 105224         VN657  Ho Chi Minh City 2022-10-01 06:50:00         Male
# 105332         TR687             Krabi 2022-10-01 08:00:00       Sydney
# 105577         PG961          Ko Samui 2022-10-01 11:10:00     Brisbane
#
#        Arrival_Gate Dep_Gate Actual_Connection_Time  % Success
# 0                B2       A2    2023-01-26 00:34:00        1.0
# 1                B2       A2    2023-01-26 00:34:00        1.0
# 2                B2       A2    2023-01-26 00:34:00        0.0
# 3                B2       A2    2023-01-26 00:34:00        1.0
# 4                B2       A2    2023-01-26 00:34:00        1.0
# ...             ...      ...                    ...        ...
# 105154         D40R      C13    2023-01-26 06:44:59        1.0
# 105155         D40R      C13    2023-01-26 06:44:59        1.0
# 105224           G5       A9    2023-01-26 06:01:14        1.0
# 105332          D48       B2    2023-01-26 04:50:36        1.0
# 105577         D40R      F35    2023-01-26 02:37:13        1.0
#
# [15570 rows x 8 columns]

# %%
datatemp5.groupby(['Arrival_Gate','Dep_Gate'])['Multi'].sum()/datatemp5.groupby(['Arrival_Gate','Dep_Gate'])['Multi'].sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:12042, in _reindex_for_setitem(value, index)
#   12041 try:
# > 12042     reindexed_value = value.reindex(index)._values
#   12043 except ValueError as err:
#   12044     # raised in MultiIndex.from_tuples, see test_insert_error_msmgs
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:5097, in Series.reindex(self, *args, **kwargs)
#    5096     kwargs.update({"index": index})
# -> 5097 return super().reindex(**kwargs)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5294, in NDFrame.reindex(self, *args, **kwargs)
#    5293 # perform the reindex on the axes
# -> 5294 return self._reindex_axes(
#    5295     axes, level, limit, tolerance, method, fill_value, copy
#    5296 ).__finalize__(self, method="reindex")
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5309, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    5308 ax = self._get_axis(a)
# -> 5309 new_index, indexer = ax.reindex(
#    5310     labels, level=level, limit=limit, tolerance=tolerance, method=method
#    5311 )
#    5313 axis = self._get_axis_number(a)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:4474, in Index.reindex(self, target, method, level, limit, tolerance)
#    4467             warnings.warn(
#    4468                 "reindexing with a non-unique Index is deprecated and "
#    4469                 "will raise in a future version.",
#    4470                 FutureWarning,
#    4471                 stacklevel=find_stack_level(inspect.currentframe()),
#    4472             )
# -> 4474 target = self._wrap_reindex_result(target, indexer, preserve_names)
#    4475 return target, indexer
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\multi.py:2555, in MultiIndex._wrap_reindex_result(self, target, indexer, preserve_names)
#    2554 try:
# -> 2555     target = MultiIndex.from_tuples(target)
#    2556 except TypeError:
#    2557     # not all tuples, see test_constructor_dict_multiindex_reindex_flat
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\multi.py:206, in names_compat.<locals>.new_meth(self_or_cls, *args, **kwargs)
#     204     kwargs["names"] = kwargs.pop("name")
# --> 206 return meth(self_or_cls, *args, **kwargs)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\multi.py:574, in MultiIndex.from_tuples(cls, tuples, sortorder, names)
#     572         tuples = np.asarray(tuples._values)
# --> 574     arrays = list(lib.tuples_to_object_array(tuples).T)
#     575 elif isinstance(tuples, list):
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\lib.pyx:2979, in pandas._libs.lib.tuples_to_object_array()
#
# ValueError: Buffer dtype mismatch, expected 'Python object' but got 'long long'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In [88], line 1
# ----> 1 datatemp5['weighted']=datatemp5.groupby(['Arrival_Gate','Dep_Gate'])['Multi'].sum()/datatemp5.groupby(['Arrival_Gate','Dep_Gate'])['SIBT'].sum()
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3978, in DataFrame.__setitem__(self, key, value)
#    3975     self._setitem_array([key], value)
#    3976 else:
#    3977     # set column
# -> 3978     self._set_item(key, value)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4172, in DataFrame._set_item(self, key, value)
#    4162 def _set_item(self, key, value) -> None:
#    4163     """
#    4164     Add series to DataFrame in specified column.
#    4165
#    (...)
#    4170     ensure homogeneity.
#    4171     """
# -> 4172     value = self._sanitize_column(value)
#    4174     if (
#    4175         key in self.columns
#    4176         and value.ndim == 1
#    4177         and not is_extension_array_dtype(value)
#    4178     ):
#    4179         # broadcast across multiple columns if necessary
#    4180         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4902, in DataFrame._sanitize_column(self, value)
#    4900     return _reindex_for_setitem(value, self.index)
#    4901 elif is_dict_like(value):
# -> 4902     return _reindex_for_setitem(Series(value), self.index)
#    4904 if is_list_like(value):
#    4905     com.require_length_match(value, self.index)
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:12049, in _reindex_for_setitem(value, index)
#   12045     if not value.index.is_unique:
#   12046         # duplicate axis
#   12047         raise err
# > 12049     raise TypeError(
#   12050         "incompatible index of inserted column with frame index"
#   12051     ) from err
#   12052 return reindexed_value
#
# TypeError: incompatible index of inserted column with frame index

# %%
# weighted average of success rate and SIBT for Pair:
datatemp5.groupby(['Arrival_Gate','Dep_Gate',])['% Success','SIBT'].
