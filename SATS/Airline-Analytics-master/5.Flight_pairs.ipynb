# %% [markdown]
# #### Read Excel

# %%
import pandas as pd
# read xls
df1_latest = pd.read_excel('20221204 DSM Sep and Oct SQ Hub Transfer DB Data (LATEST).xlsx',sheet_name='No -ve CT')
df2_cleaned = pd.read_excel('20221214 DSM Sep-Nov SQ Hub Transfer DB Data (Cleaned).xlsx',sheet_name='Sheet1')

# merge
df1_latest.head()
# Out:
#   ArrivalFlight     ORIGIN                  SIBTDateTimeOffset  \
# 0         SQ208  Melbourne  2022-09-30 16:15:00.0000000 +00:00
# 1         SQ208  Melbourne  2022-09-30 16:15:00.0000000 +00:00
# 2         SQ208  Melbourne  2022-09-30 16:15:00.0000000 +00:00
# 3         SQ208  Melbourne  2022-09-30 16:15:00.0000000 +00:00
# 4         SQ208  Melbourne  2022-09-30 16:15:00.0000000 +00:00
#
#   ArrivalFlight & Date                SIBT Day in Week  \
# 0     SQ208 09/30/2022 2022-09-30 16:15:00         Fri
# 1     SQ208 09/30/2022 2022-09-30 16:15:00         Fri
# 2     SQ208 09/30/2022 2022-09-30 16:15:00         Fri
# 3     SQ208 09/30/2022 2022-09-30 16:15:00         Fri
# 4     SQ208 09/30/2022 2022-09-30 16:15:00         Fri
#
#                    EIBTDateTimeOffset                EIBT DepartureFlight  \
# 0  2022-09-30 16:56:00.0000000 +00:00 2022-09-30 16:56:00           SQ306
# 1  2022-09-30 16:56:00.0000000 +00:00 2022-09-30 16:56:00           SQ402
# ...

# %% [markdown]
# #### Dataframe 1 (20221204 DSM Sep and Oct SQ Hub Transfer DB Data (LATEST))

# %% [markdown]
# #### Drop Duplicates

# %%
# show duplicate
df1_latest.duplicated().sum()
# Out:
# 0

# %%
# drop duplicate rows
df1_latest.drop_duplicates(inplace=True)

# %% [markdown]
# ##### Null values

# %%
# show only columns having null values
df1_latest.isnull().sum().sort_values(ascending=False)
# Out:
# EOBTDateTimeOffset           99176
# EOBT                         99176
# Flight_ID                    57143
# SQPassengerCountInfo_ID      57143
# ArrivalFlight                    0
#                              ...
# AdultPremiumBookedCount          0
# InfantBusinessBookedCount        0
# ChildBusinessBookedCount         0
# AdultBusinessBookedCount         0
# % Success                        0
# Length: 74, dtype: int64

# %% [markdown]
# ##### Columns

# %%
df1_latest.columns
# Out:
# Index(['ArrivalFlight', 'ORIGIN', 'SIBTDateTimeOffset', 'ArrivalFlight & Date',
#        'SIBT', 'Day in Week', 'EIBTDateTimeOffset', 'EIBT', 'DepartureFlight',
#        'DepartureFlight & Date', 'DESTINATION', 'SOBTDateTimeOffset', 'SOBT',
#        'EOBTDateTimeOffset', 'Flight_Departure_Time', 'Column1',
#        'Flight_Delay_Time', 'ID', 'AdultFirstBookedCount',
#        'ChildFirstBookedCount', 'InfantFirstBookedCount',
#        'AdultBusinessBookedCount', 'ChildBusinessBookedCount',
#        'InfantBusinessBookedCount', 'AdultPremiumBookedCount',
#        'ChildPremiumBookedCount', 'InfantPremiumBookedCount',
#        'AdultEconomyBookedCount', 'ChildEconomyBookedCount',
#        'InfantEconomyBookedCount', 'EOBT', 'ConnectTime (SOBT-SIBT)',
#        'ConnectTime (EOBT-EIBT)', 'Duration', 'Protection_Cost',
#        'AdultFirstAcceptedCount', 'ChildFirstAcceptedCount',
#        'InfantFirstAcceptedCount', 'AdultBusinessAcceptedCount',
# ...

# %% [markdown]
# #### Needed column

# %%
'''
'SIBTDateTimeOffset', 'SIBT', 'Day in Week','EIBTDateTimeOffset','SOBTDateTimeOffset',
'SOBT','EOBTDateTimeOffset', 'ConnectTime (SOBT-SIBT)','ConnectTime (EOBT-EIBT)','Accepted_Total','Missed_Y/N',
'''
# pick required columns
df1_latest_update = df1_latest[['ArrivalFlight','ORIGIN','ArrivalFlight & Date','EIBT','SOBTDateTimeOffset',
'DepartureFlight','DepartureFlight & Date','DESTINATION','Flight_Departure_Time','% Success']]
df1_latest_update
# Out:
#        ArrivalFlight     ORIGIN ArrivalFlight & Date                EIBT  \
# 0              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# 1              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# 2              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# 3              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# 4              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# ...              ...        ...                  ...                 ...
# 107629         SQ945   Denpasar     SQ945 10/01/2022 2022-10-01 15:15:00
# 107630         SQ193      Hanoi     SQ193 10/01/2022 2022-10-01 15:04:00
# 107631         SQ193      Hanoi     SQ193 10/01/2022 2022-10-01 15:04:00
# 107632         SQ204     Cairns     SQ204 10/01/2022 2022-10-01 15:34:00
# 107633         SQ204     Cairns     SQ204 10/01/2022 2022-10-01 15:34:00
#
#                         SOBTDateTimeOffset DepartureFlight  \
# ...

# %%
# check duplicate
df1_latest_update.duplicated().sum()
# Out:
# 0

# %%
# drop duplicates rows
df1_latest_update.drop_duplicates(inplace=True)
# Out:
# C:\Users\cvalley\AppData\Local\Temp\ipykernel_14348\1899002061.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_latest_update.drop_duplicates(inplace=True)

# %% [markdown]
# #### Dataframe 2 (20221214 DSM Sep-Nov SQ Hub Transfer DB Data (Cleaned))

# %%
df2_cleaned.head()
# Out:
#   ArrivalFlight StandPosition RegistrationNumber  \
# 0         SQ208           A17              9VSHH
# 1         SQ208           A17              9VSHH
# 2         SQ208           A17              9VSHH
# 3         SQ208           A17              9VSHH
# 4         SQ208           A17              9VSHH
#
#                    SIBTDateTimeOffset                  EIBTDateTimeOffset  \
# 0  2022-08-31 16:15:00.0000000 +00:00  2022-08-31 16:17:00.0000000 +00:00
# 1  2022-08-31 16:15:00.0000000 +00:00  2022-08-31 16:17:00.0000000 +00:00
# 2  2022-08-31 16:15:00.0000000 +00:00  2022-08-31 16:17:00.0000000 +00:00
# 3  2022-08-31 16:15:00.0000000 +00:00  2022-08-31 16:17:00.0000000 +00:00
# 4  2022-08-31 16:15:00.0000000 +00:00  2022-08-31 16:17:00.0000000 +00:00
#
#                    AIBTDateTimeOffset DepartureFlight StandPosition2  \
# 0  2022-08-31 16:21:00.0000000 +00:00           SQ882            C23
# 1  2022-08-31 16:21:00.0000000 +00:00           SQ326            A13
# ...

# %%
# show duplicate
df2_cleaned.duplicated().sum()
# Out:
# 0

# %%
# drop duplicate rows
df2_cleaned.drop_duplicates(inplace=True)

# %% [markdown]
# ##### Null values

# %%
# show only columns having null values
df2_cleaned.isnull().sum().sort_values(ascending=False)
# Out:
# EOBTDateTimeOffset                 142477
# RegistrationNumber                    795
# AIBTDateTimeOffset                    768
# EIBTDateTimeOffset                    654
# StandPosition                         641
# AOBTDateTimeOffset                     49
# StandPosition2                         21
# ArrivalFlight                           0
# arr_AdultEconomyAcceptedCount           0
# arr_FirstClassBagsWeight                0
# arr_InfantEconomyAcceptedCount          0
# arr_ChildEconomyAcceptedCount           0
# arr_ChildPremiumAcceptedCount           0
# arr_InfantPremiumAcceptedCount          0
# arr_PremiumClassBagsWeight              0
# arr_AdultPremiumAcceptedCount           0
# arr_InfantBusinessAcceptedCount         0
# arr_BusinessClassBagsWeight             0
# dep_BusinessClassCount                  0
# arr_EconomyClassBagsWeight              0
# dep_FirstClassCount                     0
# arr_AdultBusinessAcceptedCount          0
# ...

# %% [markdown]
# ##### Columns

# %%
df2_cleaned.columns
# Out:
# Index(['ArrivalFlight', 'StandPosition', 'RegistrationNumber',
#        'SIBTDateTimeOffset', 'EIBTDateTimeOffset', 'AIBTDateTimeOffset',
#        'DepartureFlight', 'StandPosition2', 'RegistrationNumber3',
#        'SOBTDateTimeOffset', 'EOBTDateTimeOffset', 'AOBTDateTimeOffset',
#        'arr_FirstClassBagCount', 'arr_BusinessClassBagCount',
#        'arr_PremiumClassBagCount', 'arr_EconomyClassBagCount',
#        'arr_AdultFirstBookedCount', 'arr_ChildFirstBookedCount',
#        'arr_InfantFirstBookedCount', 'arr_AdultBusinessBookedCount',
#        'arr_ChildBusinessBookedCount', 'arr_InfantBusinessBookedCount',
#        'arr_AdultPremiumBookedCount', 'arr_ChildPremiumBookedCount',
#        'arr_InfantPremiumBookedCount', 'arr_AdultEconomyBookedCount',
#        'arr_ChildEconomyBookedCount', 'arr_InfantEconomyBookedCount',
#        'arr_AdultFirstAcceptedCount', 'arr_ChildFirstAcceptedCount',
#        'arr_InfantFirstAcceptedCount', 'arr_AdultBusinessAcceptedCount',
# ...

# %% [markdown]
# #### Needed column

# %%
'''
'SIBTDateTimeOffset', 'RegistrationNumber','RegistrationNumber3','SOBTDateTimeOffset',
'dep_NumberOfBags','dep_WeightOfBags'
'''
# pick required columns
df2_cleaned_updated = df2_cleaned[['ArrivalFlight','StandPosition','EIBTDateTimeOffset','AIBTDateTimeOffset','DepartureFlight',
'StandPosition2','EOBTDateTimeOffset','AOBTDateTimeOffset']]
df2_cleaned_updated
# Out:
#        ArrivalFlight StandPosition                  EIBTDateTimeOffset  \
# 0              SQ208           A17  2022-08-31 16:17:00.0000000 +00:00
# 1              SQ208           A17  2022-08-31 16:17:00.0000000 +00:00
# 2              SQ208           A17  2022-08-31 16:17:00.0000000 +00:00
# 3              SQ208           A17  2022-08-31 16:17:00.0000000 +00:00
# 4              SQ208           A17  2022-08-31 16:17:00.0000000 +00:00
# ...              ...           ...                                 ...
# 159908         SQ906           F30  2022-11-30 15:34:00.0000000 +00:00
# 159909         SQ204           A21  2022-11-30 15:19:00.0000000 +00:00
# 159910         SQ204           A21  2022-11-30 15:19:00.0000000 +00:00
# 159911         SQ193           F42  2022-11-30 14:53:00.0000000 +00:00
# 159912         SQ193           F42  2022-11-30 14:53:00.0000000 +00:00
#
#                         AIBTDateTimeOffset DepartureFlight StandPosition2  \
# ...

# %%
# check duplicate
df2_cleaned_updated.duplicated().sum()
# Out:
# 2356

# %%
# drop duplicates rows
df2_cleaned_updated.drop_duplicates(inplace=True)
# Out:
# C:\Users\cvalley\AppData\Local\Temp\ipykernel_14348\894296491.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_cleaned_updated.drop_duplicates(inplace=True)

# %% [markdown]
# #### Updated DF1 and DF2 columns

# %%
df1_latest_update.columns
# Out:
# Index(['ArrivalFlight', 'ORIGIN', 'ArrivalFlight & Date', 'EIBT',
#        'SOBTDateTimeOffset', 'DepartureFlight', 'DepartureFlight & Date',
#        'DESTINATION', 'Flight_Departure_Time', '% Success'],
#       dtype='object')

# %%
df2_cleaned_updated.columns
# Out:
# Index(['ArrivalFlight', 'StandPosition', 'EIBTDateTimeOffset',
#        'AIBTDateTimeOffset', 'DepartureFlight', 'StandPosition2',
#        'EOBTDateTimeOffset', 'AOBTDateTimeOffset'],
#       dtype='object')

# %% [markdown]
# #### Intersected column names

# %%
# write common columns names to a list
common_cols = list(set(df1_latest_update.columns).intersection(df2_cleaned_updated.columns))
common_cols
# Out:
# ['DepartureFlight', 'ArrivalFlight']

# %% [markdown]
# #### Key Columns for merging

# %%
'''
Latest:
['ArrivalFlight', 'EIBT',
       'SOBTDateTimeOffset', 'DepartureFlight','Flight_Departure_Time']
'''
'''
Cleaned:
['ArrivalFlight', 'EIBTDateTimeOffset',
       'AIBTDateTimeOffset', 'DepartureFlight','EOBTDateTimeOffset', 'AOBTDateTimeOffset']
'''

# %%
df1_latest_update[['ArrivalFlight', 'EIBT',
       'SOBTDateTimeOffset', 'DepartureFlight','Flight_Departure_Time']].head(3)
# Out:
#   ArrivalFlight                EIBT                  SOBTDateTimeOffset  \
# 0         SQ208 2022-09-30 16:56:00  2022-09-30 17:10:00.0000000 +00:00
# 1         SQ208 2022-09-30 16:56:00  2022-09-30 18:35:00.0000000 +00:00
# 2         SQ208 2022-09-30 16:56:00  2022-10-01 01:30:00.0000000 +00:00
#
#   DepartureFlight               Flight_Departure_Time
# 0           SQ306  2022-09-30 17:30:00.0000000 +00:00
# 1           SQ402  2022-09-30 18:35:00.0000000 +00:00
# 2           SQ910  2022-10-01 01:30:00.0000000 +00:00

# %%
df2_cleaned_updated[['ArrivalFlight', 'EIBTDateTimeOffset',
       'DepartureFlight', 'AOBTDateTimeOffset']].head(3)
# Out:
#   ArrivalFlight                  EIBTDateTimeOffset DepartureFlight  \
# 0         SQ208  2022-08-31 16:17:00.0000000 +00:00           SQ882
# 1         SQ208  2022-08-31 16:17:00.0000000 +00:00           SQ326
# 2         SQ208  2022-08-31 16:17:00.0000000 +00:00           SQ950
#
#                    AOBTDateTimeOffset
# 0  2022-09-01 00:41:00.0000000 +00:00
# 1  2022-09-01 02:51:00.0000000 +00:00
# 2  2022-08-31 22:20:00.0000000 +00:00

# %% [markdown]
# #### Dataframe 2 EIBTDateTimeOffset

# %%
# Convert df2_cleaned_updated['EIBTDateTimeOffset'] to datetime
df2_cleaned_updated['EIBTDateTimeOffset'] = pd.to_datetime(df2_cleaned_updated['EIBTDateTimeOffset'])
df2_cleaned_updated['EIBTDateTimeOffset'].head(3)
# Out:
# C:\Users\cvalley\AppData\Local\Temp\ipykernel_14348\4083502235.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_cleaned_updated['EIBTDateTimeOffset'] = pd.to_datetime(df2_cleaned_updated['EIBTDateTimeOffset'])
# 0   2022-08-31 16:17:00+00:00
# 1   2022-08-31 16:17:00+00:00
# 2   2022-08-31 16:17:00+00:00
# Name: EIBTDateTimeOffset, dtype: datetime64[ns, UTC]

# %%
df2_cleaned_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153115 entries, 0 to 159912
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ArrivalFlight       153115 non-null  object
#  1   StandPosition       152475 non-null  object
#  2   EIBTDateTimeOffset  152461 non-null  datetime64[ns, UTC]
#  3   AIBTDateTimeOffset  152348 non-null  object
#  4   DepartureFlight     153115 non-null  object
#  5   StandPosition2      153094 non-null  object
#  6   EOBTDateTimeOffset  12755 non-null   object
#  7   AOBTDateTimeOffset  153066 non-null  object
# dtypes: datetime64[ns, UTC](1), object(7)
# memory usage: 10.5+ MB

# %%
# remove offset in EIBTDatetimeOffset 
df2_cleaned_updated['EIBTDateTimeOffset'] = df2_cleaned_updated['EIBTDateTimeOffset'].dt.tz_localize(None)
df2_cleaned_updated.head(3)
# Out:
# C:\Users\cvalley\AppData\Local\Temp\ipykernel_14348\796332629.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_cleaned_updated['EIBTDateTimeOffset'] = df2_cleaned_updated['EIBTDateTimeOffset'].dt.tz_localize(None)
#   ArrivalFlight StandPosition  EIBTDateTimeOffset  \
# 0         SQ208           A17 2022-08-31 16:17:00
# 1         SQ208           A17 2022-08-31 16:17:00
# 2         SQ208           A17 2022-08-31 16:17:00
#
#                    AIBTDateTimeOffset DepartureFlight StandPosition2  \
# 0  2022-08-31 16:21:00.0000000 +00:00           SQ882            C23
# 1  2022-08-31 16:21:00.0000000 +00:00           SQ326            A13
# 2  2022-08-31 16:21:00.0000000 +00:00           SQ950             B9
#
# ...

# %%
# check df1_latest_update['EIBT'] and df2_cleaned_updated['EIBTDateTimeOffset'] are in different format
# df1_latest_update['ArrivalFlight'] and df2_cleaned_updated['ArrivalFlight'] are same
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107634 entries, 0 to 107633
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ArrivalFlight           107634 non-null  object
#  1   ORIGIN                  107634 non-null  object
#  2   ArrivalFlight & Date    107634 non-null  object
#  3   EIBT                    107634 non-null  datetime64[ns]
#  4   SOBTDateTimeOffset      107634 non-null  object
#  5   DepartureFlight         107634 non-null  object
#  6   DepartureFlight & Date  107634 non-null  object
#  7   DESTINATION             107634 non-null  object
#  8   Flight_Departure_Time   107634 non-null  object
#  9   % Success               107634 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 8.2+ MB

# %% [markdown]
# #### Merging on key columns

# %%
print(df1_latest_update.columns)
df2_cleaned_updated.columns
# Out:
# Index(['ArrivalFlight', 'ORIGIN', 'ArrivalFlight & Date', 'EIBT',
#        'SOBTDateTimeOffset', 'DepartureFlight', 'DepartureFlight & Date',
#        'DESTINATION', 'Flight_Departure_Time', '% Success'],
#       dtype='object')
# Index(['ArrivalFlight', 'StandPosition', 'EIBTDateTimeOffset',
#        'AIBTDateTimeOffset', 'DepartureFlight', 'StandPosition2',
#        'EOBTDateTimeOffset', 'AOBTDateTimeOffset'],
#       dtype='object')

# %%
print(df1_latest_update.info())
df2_cleaned_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102032 entries, 0 to 106116
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ArrivalFlight           102032 non-null  object
#  1   ORIGIN                  102032 non-null  object
#  2   ArrivalFlight & Date    102032 non-null  object
#  3   EIBT                    102032 non-null  datetime64[ns]
#  4   SOBTDateTimeOffset      102032 non-null  object
#  5   DepartureFlight         102032 non-null  object
#  6   DepartureFlight & Date  102032 non-null  object
#  7   DESTINATION             102032 non-null  object
#  8   Flight_Departure_Time   102032 non-null  object
#  9   % Success               102032 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 8.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153115 entries, 0 to 159912
# Data columns (total 8 columns):
# ...

# %%
# check duplicate rows
print(df1_latest_update.duplicated().sum())
df2_cleaned_updated.duplicated().sum()
# Out:
# 0
# 0

# %%
# Merge df1_latest_update and df2_cleaned_updated
df_merged = pd.merge(df1_latest_update,df2_cleaned_updated,how='inner',left_on=['ArrivalFlight','EIBT','DepartureFlight'],
                                                        right_on=['ArrivalFlight','EIBTDateTimeOffset','DepartureFlight'])
df_merged
# Out:
#        ArrivalFlight     ORIGIN ArrivalFlight & Date                EIBT  \
# 0              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# 1              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# 2              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# 3              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# 4              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# ...              ...        ...                  ...                 ...
# 102201         SQ945   Denpasar     SQ945 09/30/2022 2022-09-30 14:18:00
# 102202         SQ945   Denpasar     SQ945 09/30/2022 2022-09-30 14:18:00
# 102203         SQ739     Phuket     SQ739 09/30/2022 2022-09-30 15:07:00
# 102204         SQ204     Cairns     SQ204 09/30/2022 2022-09-30 15:43:00
# 102205         SQ204     Cairns     SQ204 09/30/2022 2022-09-30 15:43:00
#
#                         SOBTDateTimeOffset DepartureFlight  \
# ...

# %%
# null values in df_merged
df_merged.isnull().sum().sort_values(ascending=False)
# Out:
# EOBTDateTimeOffset        94128
# AIBTDateTimeOffset           95
# AOBTDateTimeOffset           49
# StandPosition                31
# StandPosition2               21
# ArrivalFlight                 0
# ORIGIN                        0
# ArrivalFlight & Date          0
# EIBT                          0
# SOBTDateTimeOffset            0
# DepartureFlight               0
# DepartureFlight & Date        0
# DESTINATION                   0
# Flight_Departure_Time         0
# % Success                     0
# EIBTDateTimeOffset            0
# dtype: int64

# %%
# check duplicate rows
df_merged.duplicated().sum()
# Out:
# 0

# %%
# round off success rate to 2 decimal places
df_merged['% Success'] = df_merged['% Success'].round(2)
df_merged
# Out:
#        ArrivalFlight     ORIGIN ArrivalFlight & Date                EIBT  \
# 0              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# 1              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# 2              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# 3              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# 4              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# ...              ...        ...                  ...                 ...
# 102201         SQ945   Denpasar     SQ945 09/30/2022 2022-09-30 14:18:00
# 102202         SQ945   Denpasar     SQ945 09/30/2022 2022-09-30 14:18:00
# 102203         SQ739     Phuket     SQ739 09/30/2022 2022-09-30 15:07:00
# 102204         SQ204     Cairns     SQ204 09/30/2022 2022-09-30 15:43:00
# 102205         SQ204     Cairns     SQ204 09/30/2022 2022-09-30 15:43:00
#
#                         SOBTDateTimeOffset DepartureFlight  \
# ...

# %%
# keep only those rows where % Success is equal to 100
df_merged = df_merged[df_merged['% Success'] == 1.00]
df_merged
# Out:
#        ArrivalFlight     ORIGIN ArrivalFlight & Date                EIBT  \
# 0              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# 1              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# 3              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# 4              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# 5              SQ208  Melbourne     SQ208 09/30/2022 2022-09-30 16:56:00
# ...              ...        ...                  ...                 ...
# 102199         SQ945   Denpasar     SQ945 09/30/2022 2022-09-30 14:18:00
# 102200         SQ945   Denpasar     SQ945 09/30/2022 2022-09-30 14:18:00
# 102202         SQ945   Denpasar     SQ945 09/30/2022 2022-09-30 14:18:00
# 102203         SQ739     Phuket     SQ739 09/30/2022 2022-09-30 15:07:00
# 102204         SQ204     Cairns     SQ204 09/30/2022 2022-09-30 15:43:00
#
#                         SOBTDateTimeOffset DepartureFlight  \
# ...

# %%
# value counts % Success
df_merged['% Success'].value_counts()
# Out:
# 1.0    78780
# Name: % Success, dtype: int64

# %%
# to csv file
df_merged.to_csv('Merged_Flight_Pairs.csv',index=False)
