# %%
# open a excel file for reading
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# df=pd.read_csv('E:\\Shopify\\unitedbyblue_fashion.csv')

# df1=pd.read_csv('E:\\Shopify\\artisaire_letter.csv')
# df2=pd.read_excel('E:\\Shopify\\beneathyourmask_Beauty.xlsx')
# df3=pd.read_csv('E:\\Shopify\\beeinspiredclothing_fashion.csv')
# df4=pd.read_csv('E:\\Shopify\\unitedbyblue_fashion.csv')
# df4=pd.read_excel('E:\\Shopify\\billykirk_accessories.xlsx')
# df5=pd.read_excel('E:\\Shopify\\bkr_Beauty.xlsx')

# %%
# read all files from Shopify folder:
import os
import glob
os.chdir("E:\\Shopify")
# 
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
print(len(all_filenames))
# create bar chart of all prouct_type in all files
for i in all_filenames:
    # print(i)
    # df=pd.read_csv(i)
    # if i=='beneathyourmask_Beauty.csv':
    #     # set product_type to Beauty & Personal Care

    #     df['product_type']='Beauty & Personal Care'
    # if i=='creativebooster_products.csv':
    #     df['product_type']='Mockups & Templates'
    # df['product_type'].value_counts().plot(kind='bar')
    # plt.show()
#combine all files in the list
    combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# Out:
# 88

# %%
# combined_csv['product_type'].value_counts().plot(kind='bar')
# total number of distinct product_type
print(combined_csv['product_type'].nunique())
# change Accessory to Accessories
combined_csv['product_type']=combined_csv['product_type'].replace('Accessory','Accessories')
# change socks to Socks
combined_csv['product_type']=combined_csv['product_type'].replace('socks','Socks')
#  get the chart of all product_type where product_type is > 20
combined_csv['product_type'].value_counts()[combined_csv['product_type'].value_counts()>20].plot(kind='bar')
# Out:
# 546
# <AxesSubplot: >

# %%
import plotly.express as px
import pandas as pd

# keywords = pd.read_excel("keywords.xlsx")
# keywords=pd.read_csv("/content/KeyWords12-04.csv")
sort=combined_csv['product_type'].value_counts()
print(sort)
x=sort.index
y=sort.values

fig = px.line(x =x,y= y,labels={'x':'Product Types','y':'Frequency'})
fig.show()
# Out:
# Accessories               95
# Denim                     87
# Dresses                   82
# Beans                     66
# Tops                      61
#                           ..
# Monitor Stands             1
# PLUSH                      1
# Refill Pouch               1
# COFFEE MUG                 1
# Keyboard Carrying Case     1
# Name: product_type, Length: 546, dtype: int64

# %%
# read all files from Shopify folder:
import os
import glob
os.chdir("E:\\Shopify")
# 
extension = 'xlsx'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
print(len(all_filenames))
#combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# Out:
# 6

# %%
combined_csv.head()
# Out:
#              id                          title  \
# 0  6.637753e+12  Grandmere's Memories Camisole
# 1  7.827211e+12             Oat Straw Cardigan
# 2  7.822849e+12                 Penmanship Top
# 3  7.822847e+12        Wynn Falls County Skirt
# 4  7.795283e+12          Larkspur Bundle Dress
#
#                                               handle  \
# 0      grandmeres-memories-embroidered-knit-camisole
# 1  classic-vintage-inspired-oatmeal-v-neck-button...
# 2  feminine-romantic-vintage-inspired-black-cropp...
# 3  feminine-vintage-inspired-navy-plaid-godet-mid...
# 4  feminine-vintage-inspired-soft-blue-floral-pri...
#
#                                            body_html  \
# 0  <p>Sweetly feminine vintage inspired cream mél...
# 1  <style type="text/css"><!--\ntd {border: 1px s...
# 2  <p>Feminine, vintage inspired peasant sleeve t...
# 3  <style type="text/css"><!--\ntd {border: 1px s...
# 4  <p>This feminine, vintage-inspired short sleev...
#
# ...

# %%
df.head()
# Out:
#               id                               title  \
# 0  4170684629064                         Washing Bag
# 1  6579595903048         EZE High Rise Loose - Brynn
# 2  6579595903048         EZE High Rise Loose - Brynn
# 3  6655825707080  (R)evolutionâ¢  Woven Dog Harness
# 4  6655825707080  (R)evolutionâ¢  Woven Dog Harness
#
#                          handle  \
# 0       guppyfriend-washing-bag
# 1     eze-high-rise-loose-brynn
# 2     eze-high-rise-loose-brynn
# 3  revolution-woven-dog-harness
# 4  revolution-woven-dog-harness
#
#                                            body_html  \
# 0  <h3>Details</h3>\n<h5><strong></strong></h5>\n...
# 1  <h3>Details</h3>\n<meta charset="utf-8">\n<p>B...
# 2  <h3>Details</h3>\n<meta charset="utf-8">\n<p>B...
# 3  <h3>Details</h3>\n<meta charset="utf-8">\n<p>Y...
# 4  <h3>Details</h3>\n<meta charset="utf-8">\n<p>Y...
#
#                   created_at                 updated_at          vendor  \
# ...

# %%
# chart of the number of products in each product_type:
df['product_type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
df1['product_type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
df2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 df2.head()
#
# NameError: name 'df2' is not defined

# %%
df2=pd.read_excel('E:\\Shopify\\beneathyourmask_Beauty.xlsx')

# %%
df2.head()
# Out:
#               id                                 title  \
# 0  4525965967427  Heal <br>Whipped Skin Soufflé (tube)
# 1  4326696845379      Remedy <br>Conditioning Lip Balm
# 2     8807707910                             The Minis
# 3    11469000917   Illuminate <br>Clarifying Face Mask
# 4     8807702534     Polish <br>Detoxifying Body Scrub
#
#                                     handle  \
# 0  heal-whipped-skin-souffle-aluminum-tube
# 1             remedy-conditioning-lip-balm
# 2                          mini-collection
# 3                     clarifying-face-mask
# 4                   detoxifying-body-scrub
#
#                                            body_html  \
# 0  <!-- split -->\n<p>*2019 ALLURE BEST OF BEAUTY...
# 1  <p><!-- split --></p>\n<p>An all-day and all-n...
# 2  <meta charset="utf-8">\n<p>The minis includes ...
# 3  <!-- split --> <meta charset="utf-8">\n<p>AWAR...
# 4  <!-- split --> <meta charset="utf-8">\n<p>2020...
#
# ...

# %%
#null values in product_type
df2['product_type'].isnull().sum()
#  df2['product_type'].
# Out:
# 7

# %%
#null values in product_type
# set product_type = makeup:
df2['product_type'].fillna('makeup',inplace=True)

# %%
df2['product_type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
# open prouct_export file in appending mode:
finaldf=pd.read_csv('E:\\Shopify\\product_export.csv')
finaldf.head()
# a=pd.read_excel('E:\\Shopify\\product_export.xls')
# Out:
# Empty DataFrame
# ...

# %%
# concat the df with finaldf:
finaldf=pd.concat([finaldf,df],ignore_index=True)

# %%
finaldf.head()
# Out:
#   Handle Title Body (HTML) Vendor Product Category     product_type Tags  \
# 0    NaN   NaN         NaN    NaN              NaN    Home & Garden  NaN
# 1    NaN   NaN         NaN    NaN              NaN  Women's Apparel  NaN
# 2    NaN   NaN         NaN    NaN              NaN  Women's Apparel  NaN
# 3    NaN   NaN         NaN    NaN              NaN    Home & Garden  NaN
# 4    NaN   NaN         NaN    NaN              NaN    Home & Garden  NaN
#
#   Published Option1 Name Option1 Value  ...           image_created_at  \
# 0       NaN          NaN           NaN  ...  2022-07-05T15:58:38-04:00
# 1       NaN          NaN           NaN  ...  2021-09-07T20:37:35-04:00
# 2       NaN          NaN           NaN  ...  2021-09-07T20:37:35-04:00
# 3       NaN          NaN           NaN  ...  2022-10-04T19:50:02-04:00
# 4       NaN          NaN           NaN  ...  2022-10-04T19:50:02-04:00
#
#             image_updated_at image_product_id  \
# 0  2022-07-05T16:48:03-04:00     4.170685e+12
# ...
